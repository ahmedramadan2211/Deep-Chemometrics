# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedramadan2211/Deep-Chemometrics/blob/master/QbD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os
# !pip install RG
# !pip install pyopls
# !pip install tensorly

with zipfile.ZipFile('Colab project.zip', 'r') as zip_ref:
    zip_ref.extractall('Colab project')

# %%
# %cd /content/Colab\ project/Colab\ project
# Out:
# /content/Colab project/Colab project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functions.design import plot_blending_3d
from functions.design import run_pls
from functions.design import Run_Ridge
from functions.design import Run_LASSO
from functions.design import plot_operational_space
from functions.design import all_iterations
from functions.design import plot_all_iterations
from functions.fct_ahmed import *
import ast
plt.close('all')
np.random.seed(42)

# %%
# 🌐 All possible Calibration and Prediction Sets
# ----------------------------------------------

#selection of data for modelling
data= pd.read_excel('./savedata/Blending/data.xlsx')
data= data.query('minutes>=10 & minutes<=15')

#Modelling
iterations= all_iterations(data, model='LASSO', process=4)

#write code to excel
iterations.to_excel('./savedata/Blending/iterations_LASSO + SNV.xlsx', index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.343e+01, tolerance: 1.364e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.315e+01, tolerance: 1.364e+00
#   model = cd_fast.enet_coordinate_descent(
# ...
